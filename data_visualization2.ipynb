# %% [markdown]
# <a href="https://colab.research.google.com/github/abhay200456/Data-Visualization/blob/main/data_visualization2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
iris=sns.load_dataset ("iris")

# %%
sns.lineplot(data=iris,x="sepal_length", y= "petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(data=iris,x="sepal_length", y= "petal_length",hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.regplot(data=iris,x="sepal_length", y= "petal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.jointplot(data=iris,x="sepal_length", y= "petal_length")

# %%
sns.pairplot(data=iris)
